# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bigdata_analyst_cert/blob/main/part4/ch2/p2_type1.ipynb)

# %% [markdown]
# ## 작업형1

# %% [markdown]
# ### 문제1

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) views 컬럼 내림차순 정렬
df.sort_values('views', ascending=False, inplace=True)
# 2) 상위 10개 중에서 10번째 (최소값) 값 구하기
min_value = df['views'][:10].min()

# 3) 상위 10개 중에서 10번째 (최소값) 값 대체
df.iloc[:10,-1] = min_value

# 4) age가 80 이상의 views 컬럼 평균
cond = df['age'] >= 80
result = df[cond]['views'].mean()

# 5) 반올림하여 소수 둘째자리까지 계산
print(round(result, 2))
# Out:
# 5674.04

# %% [markdown]
# ### 문제2

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 앞에서 부터 80% 데이터 슬라이싱
line = int(len(df) * 0.8)
df = df.iloc[:line]

# 2) 결측치 채우기 전 'f1' 컬럼 표준편차 구하기
std1 = df['f1'].std()

# 3) 중앙값으로 결측치 채우기
med=df['f1'].median()
df['f1'] = df['f1'].fillna(med)

# 4) 결측치를 채운 후 'f1' 컬럼 표준편차 구하기
std2 = df['f1'].std()

# 5) 두 표준편차 차이 절대값 계산 (반올림하여 소수 둘째자리까지 계산)
result = abs(std1-std2)
print(round(result,2))
# Out:
# 3.56

# %%
# 표본 표준편차(판다스) vs 모 표준편차(넘파이)
import numpy as np
# 기본값
print("판다스 표본 표준편차", df['f1'].std())
print("넘파이 모 표준편차", np.std(df['f1']))
print("---------------------------------- ")
# ddof변경
print("판다스 모 표준편차", df['f1'].std(ddof=0))
print("넘파이 표본 표준편차", np.std(df['f1'],ddof=1))
# Out:
# 판다스 표본 표준편차 17.010788646613268
# 넘파이 모 표준편차 16.90413688272785
# ----------------------------------
# 판다스 모 표준편차 16.90413688272785
# 넘파이 표본 표준편차 17.010788646613268

# %% [markdown]
# ### 문제3.

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

# 1) 표준편차, 평균값 구하기
std = df['age'].std()
mean = df['age'].mean()

# 2) 이상치 최저, 최고 기준 구하기
lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

# 3) 이상치를 벗어나는 값(조건) 찾기
cond1 = df['age'] < lower
cond2 = df['age'] > upper

# 4) 조건에 만족하는 이상치 age합
print(df[cond1|cond2]['age'].sum())
# Out:
# 473.5
